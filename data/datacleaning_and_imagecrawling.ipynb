# %%
import requests
import pandas as pd

# %%
csv = pd.read_excel("21112023_books.xlsx")
pd.DataFrame(csv)
# Out:
#                                                    URL
# 0    https://www.fahasa.com/buoc-dau-huong-dan-luye...  \
# 1     https://www.fahasa.com/yoga-toan-thu-309285.html
# 2    https://www.fahasa.com/co-vua-nghe-thuat-trien...
# 3    https://www.fahasa.com/co-vua-don-chien-thuat-...
# 4    https://www.fahasa.com/co-vua-chien-thuat-khai...
# ..                                                 ...
# 219   https://www.fahasa.com/luoc-su-ve-triet-hoc.html
# 220  https://www.fahasa.com/nhung-diem-moi-trong-va...
# 221  https://www.fahasa.com/luat-an-toan-ve-sinh-la...
# 222  https://www.fahasa.com/bo-sach-ho-chi-minh-tac...
# 223  https://www.fahasa.com/dshcm-hoi-dap-cuoc-doi-...
#
#                                                  Image
# 0    https://cdn0.fahasa.com/media/catalog/product/...  \
# 1    https://cdn0.fahasa.com/media/catalog/product/...
# 2    https://cdn0.fahasa.com/media/catalog/product/...
# 3    https://cdn0.fahasa.com/media/catalog/product/...
# ...

# %%
images = csv['Image']
images
# Out:
# 0      https://cdn0.fahasa.com/media/catalog/product/...
# 1      https://cdn0.fahasa.com/media/catalog/product/...
# 2      https://cdn0.fahasa.com/media/catalog/product/...
# 3      https://cdn0.fahasa.com/media/catalog/product/...
# 4      https://cdn0.fahasa.com/media/catalog/product/...
#                              ...
# 219    https://cdn0.fahasa.com/skin/frontend/ma_vanes...
# 220    https://cdn0.fahasa.com/skin/frontend/ma_vanes...
# 221    https://cdn0.fahasa.com/skin/frontend/ma_vanes...
# 222    https://cdn0.fahasa.com/skin/frontend/ma_vanes...
# 223    https://cdn0.fahasa.com/skin/frontend/ma_vanes...
# Name: Image, Length: 224, dtype: object

# %%
name = csv['Name']
name
# Out:
# 0                      Bước Đầu Hướng Dẫn Luyện Khí Công
# 1                                          Yoga Toàn Thư
# 2      Cờ Vua - Nghệ Thuật Triển Khai Quân Trong Khai...
# 3      Cờ Vua - Đòn Chiến Thuật Tấn Công Trong Trung ...
# 4      Cờ Vua - Chiến Thuật Khai Cuộc - Những Điều Cầ...
#                              ...
# 219                      Lược Sử Về Triết Học - Bìa Cứng
# 220    Những Điểm Mới Trong Văn Kiện Đại Hội XIII Của...
# 221           Luật An Toàn, Vệ Sinh Lao Động (Hiện Hành)
# 222                       Bộ Sách Hồ Chí Minh - Tác Phẩm
# 223    Di Sản Hồ Chí Minh - Hỏi & Đáp Về Cuộc Đời & S...
# Name: Name, Length: 224, dtype: object

# %%
import os
import shutil
import glob

source_folder = r"C:\Users\ACER\OneDrive\Desktop\Bukus"
destination_folder = r"C:\Users\ACER\OneDrive\Desktop\Bukus\21112023\\"

# Search files with .txt extension in source directory
def transferFiles(source_folder, destination_folder):
    pattern = "\*.png"
    files = glob.glob(source_folder + pattern)

    # move the files with txt extension
    for file in files:
        # extract file name form file path
        file_name = os.path.basename(file)
        shutil.move(file, destination_folder + file_name)

# %%
import re

def no_accent_vietnamese(s):
    s = re.sub(r'[àáạảãâầấậẩẫăằắặẳẵ]', 'a', s)
    s = re.sub(r'[ÀÁẠẢÃĂẰẮẶẲẴÂẦẤẬẨẪ]', 'A', s)
    s = re.sub(r'[èéẹẻẽêềếệểễ]', 'e', s)
    s = re.sub(r'[ÈÉẸẺẼÊỀẾỆỂỄ]', 'E', s)
    s = re.sub(r'[òóọỏõôồốộổỗơờớợởỡ]', 'o', s)
    s = re.sub(r'[ÒÓỌỎÕÔỒỐỘỔỖƠỜỚỢỞỠ]', 'O', s)
    s = re.sub(r'[ìíịỉĩ]', 'i', s)
    s = re.sub(r'[ÌÍỊỈĨ]', 'I', s)
    s = re.sub(r'[ùúụủũưừứựửữ]', 'u', s)
    s = re.sub(r'[ƯỪỨỰỬỮÙÚỤỦŨ]', 'U', s)
    s = re.sub(r'[ỳýỵỷỹ]', 'y', s)
    s = re.sub(r'[ỲÝỴỶỸ]', 'Y', s)
    s = re.sub(r'[Đ]', 'D', s)
    s = re.sub(r'[đ]', 'd', s)
    return s

# %%
import urllib

for i in range(len(images)):
    name[i] = re.sub('\W', '_', name[i])
    name[i] = no_accent_vietnamese(name[i])
    name[i] = re.sub(r'_+', '_', name[i])
    urllib.request.urlretrieve(images[i], f"{name[i]}.png")

# %%
transferFiles(source_folder, destination_folder)

# %%
url = csv['URL']

# %%
import bookCrawl as bc

bookinfo = [] 
for b in range(len(url)): 
    data = bc.getData(url[b])
    bookinfo.append(data)

print("I'm done, ur geh")
# Out:
# c:\Users\ACER\OneDrive\Desktop\Bukus\bookCrawl.py:14: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 14 of the file c:\Users\ACER\OneDrive\Desktop\Bukus\bookCrawl.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   content = BeautifulSoup(requests.get(url, headers=headers).text)
# I'm done, ur geh

# %%
pd.DataFrame(bookinfo)
# Out:
#                                                    URL        Mã hàng
# 0    https://www.fahasa.com/buoc-dau-huong-dan-luye...  8935074115195  \
# 1     https://www.fahasa.com/yoga-toan-thu-309285.html  8935088555017
# 2    https://www.fahasa.com/co-vua-nghe-thuat-trien...  9786048510244
# 3    https://www.fahasa.com/co-vua-don-chien-thuat-...  9786048510282
# 4    https://www.fahasa.com/co-vua-chien-thuat-khai...  9786048510268
# ..                                                 ...            ...
# 219   https://www.fahasa.com/luoc-su-ve-triet-hoc.html  9786043937169
# 220  https://www.fahasa.com/nhung-diem-moi-trong-va...  8935279130993
# 221  https://www.fahasa.com/luat-an-toan-ve-sinh-la...  8935279138678
# 222  https://www.fahasa.com/bo-sach-ho-chi-minh-tac...  8934974166511
# 223  https://www.fahasa.com/dshcm-hoi-dap-cuoc-doi-...  8934974167891
#
#                          Tên Nhà Cung Cấp                      Tác giả
# ...

# %%
##for b in range (len(bookpage)): 
    ##data = bc.getData(bookpage[b])
    ##df = pd.concat([df, pd.DataFrame(data)], ignore_index=True)
    ##df.reset_index()

# %%
for i in range(len(images)):
    name[i] = re.sub('\W', '_', name[i])
    name[i] = no_accent_vietnamese(name[i])
    name[i] = re.sub(r'_+', '_', name[i])
    ##urllib.request.urlretrieve(images[i], f"{name[i]}.png")
    csv['Image'][i] = "/assets/" + name[i] + ".png"
    ##print(name[i])
csv
# Out:
#                                                    URL
# 0    https://www.fahasa.com/buoc-dau-huong-dan-luye...  \
# 1     https://www.fahasa.com/yoga-toan-thu-309285.html
# 2    https://www.fahasa.com/co-vua-nghe-thuat-trien...
# 3    https://www.fahasa.com/co-vua-don-chien-thuat-...
# 4    https://www.fahasa.com/co-vua-chien-thuat-khai...
# ..                                                 ...
# 219   https://www.fahasa.com/luoc-su-ve-triet-hoc.html
# 220  https://www.fahasa.com/nhung-diem-moi-trong-va...
# 221  https://www.fahasa.com/luat-an-toan-ve-sinh-la...
# 222  https://www.fahasa.com/bo-sach-ho-chi-minh-tac...
# 223  https://www.fahasa.com/dshcm-hoi-dap-cuoc-doi-...
#
#                                                  Image
# 0        /assets/Buoc_Dau_Huong_Dan_Luyen_Khi_Cong.png  \
# 1                            /assets/Yoga_Toan_Thu.png
# 2    /assets/Co_Vua_Nghe_Thuat_Trien_Khai_Quan_Tron...
# 3    /assets/Co_Vua_Don_Chien_Thuat_Tan_Cong_Trong_...
# ...

# %%
csv.to_excel("21112023_renamed.xlsx")

# %%
book_csv = pd.DataFrame(bookinfo)

# %%
book_csv.to_excel("21112023_BookInfo.xlsx")
